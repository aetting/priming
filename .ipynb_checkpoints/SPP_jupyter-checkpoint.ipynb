# %%
import processSPP

# %%
# %matplotlib inline
processSPP.runSeries(inline=1)
# Out:
# ldt-200-1
#
#
# Full
# LSA
#                             OLS Regression Results
# ...
# Dep. Variable:            LDT_200ms_Z   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.048
# Method:                 Least Squares   F-statistic:                     328.9
# Date:                Sun, 10 Apr 2016   Prob (F-statistic):           9.58e-72
# Time:                        00:57:42   Log-Likelihood:                -9013.0
# No. Observations:                6465   AIC:                         1.803e+04
# Df Residuals:                    6464   BIC:                         1.803e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# LSA           -0.2201      0.012    -18.137      0.000        -0.244    -0.196
# ...
