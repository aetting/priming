# %%
import processSPP

# %%
# %matplotlib inline
processSPP.runSeries(inline=1)
# Out:
# ldt-200-1
#
#
# Full
# LSA
#                             OLS Regression Results
# ...
# Dep. Variable:            LDT_200ms_Z   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     338.1
# Date:                Sun, 10 Apr 2016   Prob (F-statistic):           1.15e-73
# Time:                        01:10:40   Log-Likelihood:                -9113.6
# No. Observations:                6539   AIC:                         1.823e+04
# Df Residuals:                    6538   BIC:                         1.824e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# LSA           -0.2218      0.012    -18.388      0.000        -0.245    -0.198
# ...
