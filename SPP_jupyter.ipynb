# %%
import processSPP

# %% [markdown]
# First, run with models only, no frequency in regressions.

# %% [markdown]
# Condition descriptions: ldt/naming - 200/1200 SOA - raw/priming (1/0)

# %% [markdown]
# Relation types: category, backward phrasal associate, forward phrasal associate, supraordinate, script, unclassified, instrument, functional property, action, synonym, norel=unrelated primes, antonym, perceptual property.

# %%
# %matplotlib inline
processSPP.runSeries(inline=1,modsOnly=True)
# Out:
# CONDITION:
#
# ldt-200-1
# CONDITION:
#
# ldt-1200-1
# CONDITION:
#
# ldt-200-0
# CONDITION:
#
# ldt-1200-0
# CONDITION:
#
# naming-200-1
# CONDITION:
#
# naming-1200-1
# CONDITION:
#
# naming-200-0
# CONDITION:
#
# naming-1200-0
# SIMSETS

# %% [markdown]
# Now with frequency of both prime and target (or in simsets: both w1 and w2).

# %%
# %matplotlib inline
processSPP.runSeries(inline=1)
# Out:
# CONDITION:
#
# ldt-200-1
# CONDITION:
#
# ldt-1200-1
# CONDITION:
#
# ldt-200-0
# CONDITION:
#
# ldt-1200-0
# CONDITION:
#
# naming-200-1
# CONDITION:
#
# naming-1200-1
# CONDITION:
#
# naming-200-0
# CONDITION:
#
# naming-1200-0
# SIMSETS
